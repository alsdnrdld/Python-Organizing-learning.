# %% [markdown]
# # Pandas Expanding and Rolling
#
# 시계열 분석을 할 때 사용한다.

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
s = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2015', periods=1000))
s
# Out:
# 2015-01-01   -0.806472
# 2015-01-02    0.012111
# 2015-01-03   -0.830827
# 2015-01-04   -0.722210
# 2015-01-05    1.385528
#                 ...
# 2017-09-22    1.326823
# 2017-09-23   -0.186659
# 2017-09-24    0.400053
# 2017-09-25    0.775518
# 2017-09-26   -0.263066
# Freq: D, Length: 1000, dtype: float64

# %%
s.plot()
# Out:
# <AxesSubplot:>

# %%
s = s.cumsum()
s.plot()
# Out:
# <AxesSubplot:>

# %%
r = s.rolling(window=30)
r.mean()
# Out:
# 2015-01-01         NaN
# 2015-01-02         NaN
# 2015-01-03         NaN
# 2015-01-04         NaN
# 2015-01-05         NaN
#                 ...
# 2017-09-22    6.833627
# 2017-09-23    7.114527
# 2017-09-24    7.424627
# 2017-09-25    7.749852
# 2017-09-26    8.018644
# Freq: D, Length: 1000, dtype: float64

# %%
# 이동평균 
s.plot(style='k--')
r.mean().plot(style='k')
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000, 4),
                  index=pd.date_range('1/1/2015', periods=1000),
                  columns=['A', 'B', 'C', 'D'])
df = df.cumsum()

# %%
df.rolling(window=60).sum()
# Out:
#                      A            B           C            D
# 2015-01-01         NaN          NaN         NaN          NaN
# 2015-01-02         NaN          NaN         NaN          NaN
# 2015-01-03         NaN          NaN         NaN          NaN
# 2015-01-04         NaN          NaN         NaN          NaN
# 2015-01-05         NaN          NaN         NaN          NaN
# ...                ...          ...         ...          ...
# 2017-09-22  670.883688 -3696.857284  460.863393  1705.097352
# 2017-09-23  678.100766 -3686.507269  455.305889  1703.284109
# 2017-09-24  685.242516 -3675.414661  448.075524  1703.102583
# 2017-09-25  691.773335 -3664.237305  442.284962  1703.640397
# 2017-09-26  697.512714 -3652.046324  437.163277  1701.029370
#
# [1000 rows x 4 columns]

# %%
df.rolling(window=60).sum().plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.rolling(window=len(df), min_periods=1).mean().plot()

# %%
df.expanding(min_periods=1).mean().plot()

# %%
df.expanding?

# %%
dfe = pd.DataFrame({'B': [0, 1, 2, np.nan, 4]})
dfe.plot()

# %%
dfe.expanding(2).mean().plot()
